// %% [markdown]
// # TALUS Demo
// Tag And Location Unification System
//
// The goal of this demo is to satisfy the 'Preprocessing' step detailed in [our outline](https://beanland.notion.site/TALUS-d223e68cb6a5480699ceb53530398af8)
//
// I will create a function that will: take parameters to create an address and tag object with the [Samsara API](https://developers.samsara.com/docs); and add a tag to each Samsara asset that exists within its bounding box.
// ``` typescript
//     function preprocess(addressName: string, tagName: string, geofence: List[Tuple[number, number]]) -> void
// ```
//
// Specifically, I will use CES Memphis, but initially I will create a test address called "Test CES Memphis", which I will delete later.

// %% [markdown]
// ## Step 1: Exploration
// I want to test that I can filter Assets by address, and verify how many devices are within CES Memphis

// %%
const sdk = require('api')('@samsara-dev-rel/v2019.01.01#2xqng621f6l8vvz9pu');

// %%
require('dotenv').config({path:__dirname+'./.env'})
var STOKEN = process.env.SAMSARA_TOKEN

// %%
var assets;

sdk.auth(STOKEN);
sdk.V1getAllAssetCurrentLocations()
  .then(res => {
    console.log(res, "Length", res["assets"].length)
    assets = res["assets"]
  })
  .catch(err => console.error(err));
// Out:
// Promise { <pending> }
// {
//   assets: [
//     {
//       id: 281474979023263,
//       name: '150KIEU15',
//       assetSerialNumber: '150KIEU15',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979023264,
//       name: '300K3CO79',
//       assetSerialNumber: '300K3CO79',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979023266,
//       name: '150K3CO82',
//       assetSerialNumber: '150K3CO82',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979023267,
//       name: '300K3CO08',
//       assetSerialNumber: '300K3CO08',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979023271,
//       name: '75K3C025',
//       assetSerialNumber: '75K3C025',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979157819,
//       name: 'Football 2',
//       assetSerialNumber: 'G2CY-Y8Z-4XF',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979157820,
//       name: 'Football 3',
//       assetSerialNumber: 'G8MZ-TZ2-S4P',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979157821,
//       name: 'Football 1-TEST',
//       assetSerialNumber: null,
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979157822,
//       name: 'Football 4',
//       assetSerialNumber: 'GY5W-A6R-WUV',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979793321,
//       name: 'LT-4',
//       assetSerialNumber: 'LT-4',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979808838,
//       name: 'Deactivated, Previously paired with gateway GZJ6SMMFTY',
//       assetSerialNumber: null,
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979873999,
//       name: '500-3',
//       assetSerialNumber: '500-3',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979874733,
//       name: '500-1',
//       assetSerialNumber: '500-1',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911072,
//       name: '65-2',
//       assetSerialNumber: '65-2',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911073,
//       name: '1003',
//       assetSerialNumber: '1003',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911074,
//       name: '45-13',
//       assetSerialNumber: '45-13',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911075,
//       name: '1004',
//       assetSerialNumber: '1004',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911076,
//       name: '500-4',
//       assetSerialNumber: '500-4',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911077,
//       name: 'G9BX-E7V-S38',
//       assetSerialNumber: '45-7',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911078,
//       name: '1203',
//       assetSerialNumber: '1203',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911079,
//       name: '3003',
//       assetSerialNumber: '3003',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911080,
//       name: '45-5',
//       assetSerialNumber: '45-5',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911081,
//       name: '2001',
//       assetSerialNumber: '2001',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911082,
//       name: '2012',
//       assetSerialNumber: '2012',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911083,
//       name: '65-1',
//       assetSerialNumber: '65-1',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911084,
//       name: '45K3CO22',
//       assetSerialNumber: '45K3CO22',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911085,
//       name: '1201',
//       assetSerialNumber: '1201',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911086,
//       name: '3004',
//       assetSerialNumber: '3004',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911087,
//       name: '2005',
//       assetSerialNumber: '2005',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911088,
//       name: 'ELT-3',
//       assetSerialNumber: 'ELT-3',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911089,
//       name: '3002',
//       assetSerialNumber: '3002',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911090,
//       name: '2002',
//       assetSerialNumber: '2002',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911091,
//       name: '50-3',
//       assetSerialNumber: '50-3',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911092,
//       name: 'G3E7-V9A-SE7',
//       assetSerialNumber: '180-4',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911093,
//       name: '150-3',
//       assetSerialNumber: '150-3',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911094,
//       name: 'SD4822',
//       assetSerialNumber: 'N1609091',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911095,
//       name: 'G6PF-9EZ-7NV',
//       assetSerialNumber: '150-5',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911096,
//       name: '2501',
//       assetSerialNumber: '2501',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911097,
//       name: 'G7UM-474-42D',
//       assetSerialNumber: '125-6',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911098,
//       name: 'G9ED-UU6-5CA',
//       assetSerialNumber: '150-4',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911099,
//       name: 'DV4803 (Battery)',
//       assetSerialNumber: 'KB168318',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911100,
//       name: '50-2',
//       assetSerialNumber: '50-2',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911101,
//       name: '2007',
//       assetSerialNumber: '2007',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911102,
//       name: 'SD5303R',
//       assetSerialNumber: 'KH151524',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911103,
//       name: '14-1',
//       assetSerialNumber: '14-1',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911104,
//       name: '45-6',
//       assetSerialNumber: '45-6',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911105,
//       name: 'GKS3-V7E-75W',
//       assetSerialNumber: '125-5',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911106,
//       name: '75K3C029',
//       assetSerialNumber: '75K3C029',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911107,
//       name: 'DV2801LG',
//       assetSerialNumber: '9B704695',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911108,
//       name: '25-1',
//       assetSerialNumber: '25-1',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911109,
//       name: '2502',
//       assetSerialNumber: '2502',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911110,
//       name: 'GZ58-6UV-5K5',
//       assetSerialNumber: '70-2',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911111,
//       name: '300K3CO65',
//       assetSerialNumber: '300K3CO65',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911112,
//       name: 'B7178891',
//       assetSerialNumber: 'B7178891',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911113,
//       name: '28B10936',
//       assetSerialNumber: '28B10936',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911114,
//       name: 'G5JF-8ES-89Z',
//       assetSerialNumber: '78C10208',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911115,
//       name: '75KISO19',
//       assetSerialNumber: '75KISO19',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911116,
//       name: '28B10934',
//       assetSerialNumber: '28B10934',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911117,
//       name: '72B120074',
//       assetSerialNumber: '72B120074',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911118,
//       name: '75KISO18',
//       assetSerialNumber: '75KISO18',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911119,
//       name: 'F22736',
//       assetSerialNumber: 'F22736',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911120,
//       name: 'HEAT15017',
//       assetSerialNumber: 'HEAT15017',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911121,
//       name: 'B7178889',
//       assetSerialNumber: 'B7178889',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911122,
//       name: 'HEAT15032',
//       assetSerialNumber: 'HEAT15032',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911123,
//       name: '909329',
//       assetSerialNumber: '909329',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911124,
//       name: '300K3CO58',
//       assetSerialNumber: '300K3CO58',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911125,
//       name: 'HEAT15021',
//       assetSerialNumber: 'HEAT15021',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911126,
//       name: 'UP141',
//       assetSerialNumber: 'UP141',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911127,
//       name: '000231',
//       assetSerialNumber: '000231',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911128,
//       name: 'UP123',
//       assetSerialNumber: 'UP123',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911129,
//       name: 'F22239',
//       assetSerialNumber: 'F22239',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911130,
//       name: '78C10203',
//       assetSerialNumber: '78C10203',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911131,
//       name: '30TON0023',
//       assetSerialNumber: '30TON0023',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911132,
//       name: '30TON0083',
//       assetSerialNumber: '30TON0083',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911133,
//       name: 'G68F-XJG-2TC',
//       assetSerialNumber: 'D1450210',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911134,
//       name: '30TON0031',
//       assetSerialNumber: '30TON0031',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911135,
//       name: '30TON0081',
//       assetSerialNumber: '30TON0081',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911136,
//       name: 'G78H-ZFB-KVB',
//       assetSerialNumber: null,
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911137,
//       name: '78C10154',
//       assetSerialNumber: '78C10154',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911138,
//       name: 'SD4819',
//       assetSerialNumber: 'P1609205',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911139,
//       name: 'GAJJ-6MA-P5J',
//       assetSerialNumber: null,
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911140,
//       name: '9ZR01593',
//       assetSerialNumber: '9ZR01593',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911141,
//       name: 'GDS4-44E-GPR',
//       assetSerialNumber: null,
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911142,
//       name: 'AEH12680',
//       assetSerialNumber: 'AEH12680',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911143,
//       name: 'D1630161',
//       assetSerialNumber: 'D1630161',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911144,
//       name: '150K3C134',
//       assetSerialNumber: '150K3C134',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911145,
//       name: 'GJYU-S6Y-NPU',
//       assetSerialNumber: null,
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911146,
//       name: '9NR04792/9NR04793',
//       assetSerialNumber: '9NR04792/9NR04793',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911147,
//       name: 'UP155',
//       assetSerialNumber: 'UP155',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911148,
//       name: '30TON0019',
//       assetSerialNumber: '30TON0019',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911149,
//       name: 'GSZ7-T5J-RMC',
//       assetSerialNumber: null,
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911150,
//       name: 'UP058',
//       assetSerialNumber: 'UP058',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911151,
//       name: '150K3C117',
//       assetSerialNumber: '150K3C117',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911152,
//       name: 'D1450175',
//       assetSerialNumber: 'D1450175',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911153,
//       name: 'DV4801',
//       assetSerialNumber: 'KB168319',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911154,
//       name: '300K3CO32',
//       assetSerialNumber: '300K3CO32',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911155,
//       name: '9ZR02763',
//       assetSerialNumber: '9ZR02763',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911156,
//       name: '45KVA17',
//       assetSerialNumber: '45KVA17',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911157,
//       name: '75K3C033',
//       assetSerialNumber: '75K3C033',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     {
//       id: 281474979911158,
//       name: '150K3CO23',
//       assetSerialNumber: '150K3CO23',
//       engineHours: 0,
//       cable: [Object],
//       location: [Array]
//     },
//     ... 2035 more items
//   ],
//   pagination: {
//     hasNextPage: false,
//     hasPrevPage: false,
//     startCursor: 'MjgxNDc0OTc5MDIzMjYz',
//     endCursor: 'MjgxNDc0OTgyNjM0NDc2'
//   }
// } Length 2135

// %%
const MEMPHIS = "CES Memphis"

// %%
var memphis_assets = assets.filter(e => e["location"][0]["location"] === MEMPHIS)
console.log("There are", memphis_assets.length, "assets in", MEMPHIS)
// Out:
// There are 355 assets in CES Memphis

// %% [markdown]
// Checking on the Samsara [cloud portal](https://cloud.samsara.com/o/10001042/fleet/list?bounds=28.564133%2C-101.170133%2C44.581756%2C-75.659879&z=6), we can see visually that there are around this number of assets in the Memphis area. Positive discrepancies can be accounted for with devices in the greater Memphis area.
// ![Cloud image](./img/cloud_image.png)

// %% [markdown]
// ## Step 2: Creating Objects
// Next, I want to create a new Address object, then a new tag object with the API. These are both simple API calls, however I need a Geofence Object, which I will get from the existing CES Memphis Address Object

// %% [markdown]
// ### Geofence Object
// In the API, there are 2 options for creating a Geofence:
// * Circle
// * Polygon
//
// In the existing Memphis site, it is defined as a circle, but in practice we will use the polygon stored about the Skyfall map. A polygon requires at least 3 but no more than 40 vertices. The Skyfall DB does not expressly store the geometry of the map, but does store the centre (lat, lng) and the image. From those two, I can try to figure out the bounds, but that is down the road
//
// For this demo, I will be using the Circle option, as that is what already exists, but this can easily be changed for practice.

// %%
const MEMPHIS_ID = 26709829 // retreived from API
const GEOFENCE = {"circle": {
    "latitude": 35.05687169999999,
    "longitude": -89.9464868,
    "radiusMeters": 2555
  }} 
const TEST_ADDRESS = "Test CES Memphis"
const TEST_TAG = "Test_0001"

// %% [markdown]
// ### Create Address
//
// Addresses to delete: 40108928,40109193,40110375, '40110763', '40110974'

// %%
var params = {
    geofence: GEOFENCE, 
    name: TEST_ADDRESS,
    formattedAddress: "3500 Air Center Cove, Memphis, TN 38118, USA"
}

sdk.auth(STOKEN);
sdk.createAddress(params)
  .then(res => console.log(res))
  .catch(err => console.error(err));
// Out:
// Promise { <pending> }
// {
//   data: {
//     id: '40110375',
//     name: 'Test CES Memphis',
//     createdAtTime: '2022-10-06T15:12:30.782034755Z',
//     formattedAddress: '3500 Air Center Cove, Memphis, TN 38118, USA',
//     geofence: { circle: [Object] },
//     latitude: 35.05687169999999,
//     longitude: -89.9464868
//   }
// }

// %%
function createAddress(name, geofence, formattedAddress)

// %% [markdown]
// ### Create Tag
// Tags to delete: 3759296

// %%
tagParams = {name: TEST_TAG}

sdk.auth(STOKEN);
sdk.createTag(tagParams)
  .then(res => console.log(res))
  .catch(err => console.error(err));
// Out:
// Promise { <pending> }
// {
//   data: {
//     id: '3759296',
//     name: 'Test_0001',
//     vehicles: [],
//     drivers: [],
//     assets: [],
//     machines: [],
//     sensors: [],
//     addresses: [],
//     externalIds: { 'samsara.name': 'Test_0001' }
//   }
// }

// %%
var tag_id = 3759296

// %% [markdown]
// ## Step 3: Adding Tags to Assets
// * Filter assets by location
// * Add tags to those assets
// * Bish Bash Bosh

// %%
async function createTagWithAssets(addressName, tagName) {
    return new Promise(async (resolve, reject) => {
        sdk.auth(STOKEN);
        var assets = (await sdk.V1getAllAssetCurrentLocations())["assets"]

        var filtered_assets = assets.filter(e => e["location"][0]["location"] === addressName)
        var assetIDs = filtered_assets.map(e => e["id"])
        sdk.createTag({name: tagName, assets: assetIDs}).then(res => {
            resolve(res["data"]["id"])
        })
    })
}

var resultID; 
createTagWithAssets(TEST_ADDRESS, "Test_0002")
    .then(id => {
        resultID = id
        console.log("Success! New ID: ", id)
    })
    .catch(err => console.error(err))
// Out:
// Promise { <pending> }
// Success! New ID:  3759320

// %% [markdown]
// ### Testing
// Success criteria
// * 355 assets in tag

// %%
const NUM_MEMPHIS_ASSETS = 355

// %%
sdk.getTag({id: resultID})
  .then(res => {
    console.log(res)
    if (res["data"]["assets"].length != NUM_MEMPHIS_ASSETS)
      throw Error("Inocorrect number of assets: expected: ", NUM_MEMPHIS_ASSETS, "Found:", res["data"]["assets"].length)
    else
      console.log("Success!")
    })
.catch(err => console.error(err));
// Out:
// Promise { <pending> }
// {
//   data: {
//     id: '3759320',
//     name: 'Test_0002',
//     vehicles: [],
//     drivers: [],
//     assets: [],
//     machines: [],
//     sensors: [],
//     addresses: [],
//     externalIds: { 'samsara.name': 'Test_0002' }
//   }
// }
// Error: Inocorrect number of assets: expected:
//     at evalmachine.<anonymous>:5:13
//     at runMicrotasks (<anonymous>)
//     at processTicksAndRejections (node:internal/process/task_queues:96:5)
